# %%
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, KFold
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
df1=pd.read_csv('titanic.csv')
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0            NaN         0       3
# 1          893.0         1       3
# 2          894.0         0       2
# 3          895.0         0       3
# 4          896.0         1       3
# ..           ...       ...     ...
# 413       1305.0         0       3
# 414       1306.0         1       1
# 415       1307.0         0       3
# 416       1308.0         0       3
# 417       1309.0         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df1.isnull().sum()
# Out:
# PassengerId      1
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df2=df1.drop(['PassengerId', 'Age','Cabin'], axis=1)
df2
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                              Kelly, Mr. James    male
# 1           1       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2           0       2                     Myles, Mr. Thomas Francis    male
# 3           0       3                              Wirz, Mr. Albert    male
# 4           1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..        ...     ...                                           ...     ...
# 413         0       3                            Spector, Mr. Woolf    male
# 414         1       1                  Oliva y Ocana, Dona. Fermina  female
# 415         0       3                  Saether, Mr. Simon Sivertsen    male
# 416         0       3                           Ware, Mr. Frederick    male
# 417         0       3                      Peter, Master. Michael J    male
#
#      SibSp  Parch              Ticket      Fare Embarked
# ...

# %%
df3 = df2.dropna(how='any')
df3
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                              Kelly, Mr. James    male
# 1           1       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2           0       2                     Myles, Mr. Thomas Francis    male
# 3           0       3                              Wirz, Mr. Albert    male
# 4           1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..        ...     ...                                           ...     ...
# 413         0       3                            Spector, Mr. Woolf    male
# 414         1       1                  Oliva y Ocana, Dona. Fermina  female
# 415         0       3                  Saether, Mr. Simon Sivertsen    male
# 416         0       3                           Ware, Mr. Frederick    male
# 417         0       3                      Peter, Master. Michael J    male
#
#      SibSp  Parch              Ticket      Fare Embarked
# ...

# %%
df3.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %%
X = df3.drop(["Name","Sex","Embarked","Ticket"],axis=1)
y= df3["Survived"]

# %%
X
# Out:
#      Survived  Pclass  SibSp  Parch      Fare
# 0           0       3      0      0    7.8292
# 1           1       3      1      0    7.0000
# 2           0       2      0      0    9.6875
# 3           0       3      0      0    8.6625
# 4           1       3      1      1   12.2875
# ..        ...     ...    ...    ...       ...
# 413         0       3      0      0    8.0500
# 414         1       1      0      0  108.9000
# 415         0       3      0      0    7.2500
# 416         0       3      0      0    8.0500
# 417         0       3      1      1   22.3583
#
# [417 rows x 5 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 413    0
# 414    1
# 415    0
# 416    0
# 417    0
# Name: Survived, Length: 417, dtype: int64

# %%
kf=KFold(n_splits=5)
kf.get_n_splits(X,y)
# Out:
# 5

# %%
clf=DecisionTreeClassifier()
for train_ind, test_ind in kf.split(X,y):
    clf.fit(X.iloc[train_ind,:],y.iloc[train_ind])
    pred=clf.predict(X.iloc[test_ind,:])
    print("Accuracy For Each fold of data are")
    print(round(accuracy_score(y.iloc[test_ind],pred),3))
# Out:
# Accuracy For Each fold of data are
# 1.0
# Accuracy For Each fold of data are
# 1.0
# Accuracy For Each fold of data are
# 1.0
# Accuracy For Each fold of data are
# 1.0
# Accuracy For Each fold of data are
# 1.0

# %%
cv =cross_val_score(DecisionTreeClassifier(),X,y,cv=5,scoring='accuracy')
print("Accuracy of all the folds after the cross validation are",cv)
# Out:
# Accuracy of all the folds after the cross validation are [1. 1. 1. 1. 1.]

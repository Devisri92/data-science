# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
exam = pd.read_csv('exam.csv')
exam
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group B                 high school  free/reduced
# 1      male        group A          associate's degree      standard
# 2      male        group C            some high school  free/reduced
# 3    female        group D            some high school      standard
# 4    female        group A           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group D                some college      standard
# 996    male        group E             master's degree  free/reduced
# 997  female        group C                some college  free/reduced
# 998  female        group A          associate's degree      standard
# 999  female        group B          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
exam.info()
exam
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group B                 high school  free/reduced
# 1      male        group A          associate's degree      standard
# ...

# %%
exam.describe()
exam
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group B                 high school  free/reduced
# 1      male        group A          associate's degree      standard
# 2      male        group C            some high school  free/reduced
# 3    female        group D            some high school      standard
# 4    female        group A           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group D                some college      standard
# 996    male        group E             master's degree  free/reduced
# 997  female        group C                some college  free/reduced
# 998  female        group A          associate's degree      standard
# 999  female        group B          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
exam1 =  ["math score","reading score","writing score"]
fig, ax = plt.subplots(1,3,figsize =[10,10])
for y,subplot in zip(exam1,ax.flatten()):
    plot = sns.distplot(a=exam[y], ax = subplot,hist = False)
    plot.set_xlabel(y)
# Out:
# C:\Users\admin\miniconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\admin\miniconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # Find the mean and standard deviation using the scipylibrary

# %%
for x in exam1:
    print(scipy.mean(exam[x]))
    print(scipy.std(exam[x]))
# Out:
# 67.095
# 14.674875638314623
# 70.189
# 13.809897863489072
# 68.85
# 14.457921704034781
# C:\Users\admin\AppData\Local\Temp\ipykernel_4528\3704648203.py:2: DeprecationWarning: scipy.mean is deprecated and will be removed in SciPy 2.0.0, use numpy.mean instead
#   print(scipy.mean(exam[x]))
# C:\Users\admin\AppData\Local\Temp\ipykernel_4528\3704648203.py:3: DeprecationWarning: scipy.std is deprecated and will be removed in SciPy 2.0.0, use numpy.std instead
#   print(scipy.std(exam[x]))

# %% [markdown]
# # Find skewness and kurtosis using the stats module from the scipylibrary

# %%
for x in exam1:
    print('mean of the',x ,stats.skew(exam[x]))
    print('standard deviation of the',x,stats.kurtosis(exam[x]))
# Out:
# mean of the math score -0.2473493688814472
# standard deviation of the math score 0.0344647614728113
# mean of the reading score -0.19513845535327878
# standard deviation of the reading score -0.10424341727490205
# mean of the writing score -0.1920097699458864
# standard deviation of the writing score -0.00877069922851037

# %%
#Find Standard Normal Distribution(z-score) using the statsmodule from the scipylibrary

# %%
for x in exam1:
    print(stats.zscore(exam[x]))
# Out:
# 0     -0.960485
# 1      0.402388
# 2     -1.505635
# 3      0.879394
# 4      0.470532
#          ...
# 995   -1.233060
# 996    0.743107
# 997   -2.050784
# 998   -0.960485
# 999    1.424544
# Name: math score, Length: 1000, dtype: float64
# 0     -1.461922
# 1      0.203550
# 2     -1.968805
# 3      0.203550
# 4      1.796610
#          ...
# 995   -1.751570
# 996    0.565609
# 997   -1.172275
# 998   -1.099863
# 999    2.158669
# Name: reading score, Length: 1000, dtype: float64
# 0     -1.580448
# 1     -0.058791
# 2     -1.926280
# 3      0.494539
# 4      1.601198
#          ...
# 995   -0.957952
# 996    0.771204
# 997   -1.096285
# 998   -0.612121
# 999    2.154528
# Name: writing score, Length: 1000, dtype: float64

# %%
fig, ax = plt.subplots(1,3,figsize =[10,10])
for y,subplot in zip(exam1,ax.flatten()):
    plot = sns.distplot(stats.zscore(exam[y]), ax = subplot,hist = False)
    plot.set_xlabel(y)
# Out:
# C:\Users\admin\miniconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\admin\miniconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

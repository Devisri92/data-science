# %%
import pandas as pd
df1 = pd.read_csv("big_bang_theory_episodes.csv")
print(df1)
# Out:
#      season  episode_num_in_season  episode_num_overall  \
# 0         1                      1                    1
# 1         1                      2                    2
# 2         1                      3                    3
# 3         1                      4                    4
# 4         1                      5                    5
# ..      ...                    ...                  ...
# 274      12                     20                  275
# 275      12                     21                  276
# 276      12                     22                  277
# 277      12                     23                  278
# 278      12                     24                  279
#
#                           title       directed_by  \
# 0                         Pilot     James Burrows
# 1       The Big Bran Hypothesis   Mark Cendrowski
# 2     The Fuzzy Boots Corollary   Mark Cendrowski
# 3      The Luminous Fish Effect   Mark Cendrowski
# ...

# %%
  df1.groupby('directed_by').count()
# Out:
#                   season  episode_num_in_season  episode_num_overall  title  \
# directed_by
# Andrew D. Weyman       1                      1                    1      1
# Anthony Rich          12                     12                   12     12
# Gay Linvill            2                      2                    2      2
# Howard Murray          2                      2                    2      2
# James Burrows          1                      1                    1      1
# Joel Murray            1                      1                    1      1
# Kristy Cecil           2                      2                    2      2
# Mark Cendrowski      244                    244                  244    244
# Nikki Lorre            6                      6                    6      6
# Peter Chakos           7                      7                    7      7
# Ted Wass               1                      1                    1      1
#
# ...

# %%
 df2=df1.groupby('directed_by').get_group('Mark Cendrowski')
 df2
# Out:
#      season  episode_num_in_season  episode_num_overall  \
# 1         1                      2                    2
# 2         1                      3                    3
# 3         1                      4                    4
# 5         1                      6                    6
# 6         1                      7                    7
# ..      ...                    ...                  ...
# 272      12                     18                  273
# 273      12                     19                  274
# 274      12                     20                  275
# 277      12                     23                  278
# 278      12                     24                  279
#
#                            title      directed_by  \
# 1        The Big Bran Hypothesis  Mark Cendrowski
# 2      The Fuzzy Boots Corollary  Mark Cendrowski
# 3       The Luminous Fish Effect  Mark Cendrowski
# 5      The Middle Earth Paradigm  Mark Cendrowski
# ...

# %%
#question no 2

import pandas as pd
df3 = pd.read_csv("big_bang_theory_episodes.csv")
print(df3)
# Out:
#      season  episode_num_in_season  episode_num_overall  \
# 0         1                      1                    1
# 1         1                      2                    2
# 2         1                      3                    3
# 3         1                      4                    4
# 4         1                      5                    5
# ..      ...                    ...                  ...
# 274      12                     20                  275
# 275      12                     21                  276
# 276      12                     22                  277
# 277      12                     23                  278
# 278      12                     24                  279
#
#                           title       directed_by  \
# 0                         Pilot     James Burrows
# 1       The Big Bran Hypothesis   Mark Cendrowski
# 2     The Fuzzy Boots Corollary   Mark Cendrowski
# 3      The Luminous Fish Effect   Mark Cendrowski
# ...

# %%
df1.groupby(['directed_by','']).count()
# Out:
#                                                                      season  \
# directed_by      written_by
# Andrew D. Weyman Story by: Jennifer GlickmanTeleplay by: Dave Go...       1
# Anthony Rich     Chuck Lorre & Bill Prady & Lee Aronsohn & Steve...       1
#                  Story by: Bill Prady & Eric Kaplan & Jim Reynol...       1
#                  Story by: Chuck Lorre & Bill Prady & Dave Goets...       1
#                  Story by: Chuck Lorre & Bill Prady & Steve Holl...       1
# ...                                                                     ...
# Peter Chakos     Story by: Chuck Lorre & Eric Kaplan & Adam Fabe...       1
#                  Story by: Chuck Lorre & Jim Reynolds & Jeremy H...       1
#                  Story by: Chuck Lorre & Lee Aronsohn & Steven M...       1
#                  Story by: Chuck Lorre & Steven Molaro & Maria F...       1
# Ted Wass         Story by: Dave Goetsch & Steven MolaroTeleplay ...       1
#
# ...

# %%
reviews.loc[:, []
